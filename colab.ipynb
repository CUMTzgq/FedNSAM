# %%
# !git clone --branch clean-dev --single-branch https://github.com/CUMTzgq/FedNSAM.git
# %cd FedNSAM
# %pip install -r requirements.txt

# %%
# !git pull origin clean-dev

# %%
import torch
torch.cuda.is_available()

# %%
# !python  main_FedNSAM.py --alg FedNSAM --lr 1e-1 --data_name CIFAR10 --alpha_value 0.6 --alpha  10  --epoch 301  --extname FedNSAM --lr_decay 2 --gamma 0.85  --CNN   resnet18 --E 5 --batch_size 50   --gpu 0 --p 1 --num_gpus_per 0.1 --normalization BN --selection 0.1 --print 0 --pre 1 --num_workers 100 --preprint 10  --rho 0.01 --lora 0 --K 50

# %%
# !python -u main_FedNSAM.py --alg FedNSAM --lr 1e-1 --data_name CIFAR10 --alpha_value 0.6 --alpha 10 --epoch 2 --extname FedNSAM --lr_decay 2 --gamma 0.85 --CNN resnet18 --E 1 --batch_size 16 --gpu 0 --p 1 --num_gpus_per 1 --normalization BN --selection 0.1 --print 0 --pre 1 --num_workers 10 --preprint 1 --rho 0.01 --lora 0 --K 5
# Out:
# 0
# gpu_idx 0
# True
# cuda
# 加载已有数据索引文件: num_workers_10-alpha_value_0.6-data_CIFAR10
# 2026-04-06 08:42:17,622	INFO worker.py:2013 -- Started a local Ray instance.
# /usr/local/lib/python3.12/dist-packages/ray/_private/worker.py:2052: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# (raylet) Warning: The actor DataWorker is very large (42 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# ...

# %%
# !python -u main_FedNSAM.py \
  --alg FedNSAM \
  --lr 1e-1 \
  --data_name CIFAR10 \
  --alpha_value 0.6 \
  --alpha 10 \
  --epoch 20 \
  --extname FedNSAM \
  --lr_decay 2 \
  --gamma 0.85 \
  --CNN resnet18 \
  --E 1 \
  --batch_size 32 \
  --gpu 0 \
  --p 1 \
  --num_gpus_per 1 \
  --normalization BN \
  --selection 0.2 \
  --print 0 \
  --pre 1 \
  --num_workers 20 \
  --preprint 2 \
  --rho 0.01 \
  --lora 0 \
  --K 10
# Out:
# 0
# gpu_idx 0
# True
# cuda
# Client 0 label histogram → Counter({5: 690, 0: 622, 9: 358, 8: 210, 1: 210, 2: 206, 4: 91, 7: 54, 6: 32, 3: 27})
# Client 1 label histogram → Counter({5: 683, 0: 538, 4: 350, 6: 277, 9: 261, 3: 155, 2: 102, 8: 71, 7: 36, 1: 27})
# Client 2 label histogram → Counter({4: 894, 1: 889, 7: 231, 5: 115, 2: 104, 6: 75, 9: 69, 0: 60, 8: 52, 3: 11})
# Client 3 label histogram → Counter({6: 776, 4: 623, 7: 421, 9: 291, 2: 266, 3: 76, 0: 19, 8: 10, 5: 9, 1: 9})
# Client 4 label histogram → Counter({5: 1591, 1: 341, 0: 183, 7: 171, 3: 106, 2: 58, 8: 26, 4: 18, 9: 6})
# mean label std: 281.41411797279255
# 生成并保存新数据索引文件: num_workers_20-alpha_value_0.6-data_CIFAR10
# 2026-04-06 08:48:50,149	INFO worker.py:2013 -- Started a local Ray instance.
# ...
